# %%
import pandas as pd

from bs4 import BeautifulSoup

from nltk import word_tokenize

# %%
df = pd.read_csv(r"D:\data\openparliament\hansards_with_party_en.csv")
# Out:
# C:\Users\alecr\Anaconda3\envs\openparliament\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (20,23,28,29,30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [raw]
# df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.to_csv(r"D:\data\openparliament\hansards_with_party_en.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    id  politician_id  riding_id  party_id    end_date  \
# 0           0  2611           3465      35066         4  2005-11-29
# 1           1  3210           3465      70224         4  1997-04-27
# 2           2  4305            173      70358         1          \N
# 3           3  1534            173      47007         1  2015-10-19
# 4           4  1541             43      47014         1  2015-10-19
#
#    start_date    id.1  document_id                    time  ... source_id  \
# 0  1997-09-22  232373         1878  2001-05-03 13:50:00-04  ...       NaN
# 1  1994-01-17  232373         1878  2001-05-03 13:50:00-04  ...       NaN
# 2  2015-10-19  645329          388  2008-02-14 13:15:00-05  ...   2324890
# 3  2004-10-04  645329          388  2008-02-14 13:15:00-05  ...   2324890
# 4  2004-10-04  313253         1621  2004-02-06 10:05:00-05  ...       NaN
#
#                                       who_context_en                 slug  \
# ...

# %% [raw]
# df_column_names = ['id', 'politician_id', 'riding_id', 'party_id', 'end_date', 'start_date','id', 'document_id', 'time', 'h1_en', 'h2_en', 'member_id', 'who_en', 'content_en', 'sequence_en',
#                 'wordcount', 'politician_id', 'procedural', 'h3_en','who_hocid', 'content_fr','statement_type', 'written_question', 'source_id',
#                 'who_context_en', "slug", 'urlcache', 'h1_fr', 'h2_fr', 'h3_fr', 'who_fr', 'who_context_fr', 'wordcount_en']

# %% [raw]
# df.columns = df_column_names

# %% [markdown]
# getting the english statements

# %%
df.shape
# Out:
# (896451, 33)

# %% [raw]
# df = df[df.h2_en.notnull()]
# #not necessary

# %% [raw]
# df.head()

# %%
def tokenize_column (row):
    soup = BeautifulSoup(row)
    text = soup.text.lower()
    words = word_tokenize(text)
    return words

# %%
tokenize_column(df.content_en[10])
# Out:
# ['mr.',
#  'speaker',
#  ',',
#  'i',
#  'would',
#  'like',
#  'to',
#  'commend',
#  'my',
#  'colleague',
#  'from',
#  'lethbridge',
#  'who',
#  'has',
#  'brought',
#  'forward',
#  'this',
#  'private',
#  'member',
#  "'s",
#  'bill',
#  ',',
#  'bill',
#  'c-325',
#  ',',
#  'an',
#  'act',
#  'to',
#  'amend',
#  'the',
#  'income',
#  'tax',
#  'act',
#  '(',
#  'deduction',
#  'for',
#  'volunteer',
#  'emergency',
#  'service',
#  ')',
#  '.\\nfor',
#  'my',
#  'good',
#  'friend',
#  ',',
#  'my',
#  'colleague',
#  'from',
#  'lethbridge',
#  ',',
#  'whose',
#  'riding',
#  'encompasses',
#  'a',
#  'lot',
#  'of',
#  'rural',
#  'areas',
#  ',',
#  'this',
#  'is',
#  'extremely',
#  'important',
#  '.',
#  'volunteers',
#  'are',
#  'extremely',
#  'important',
#  'in',
#  'rural',
#  'areas',
#  'as',
#  'they',
#  'man',
#  'emergency',
#  'services',
#  'and',
#  'are',
#  'providing',
#  'the',
#  'quality',
#  'of',
#  'life',
#  'and',
#  'that',
# ...

# %% [raw]
# df.drop('tokenized_content',axis=1, inplace=True)

# %%
df_small['new_row'] = df_small.content_en.apply(tokenize_column)
# Out:
# <ipython-input-36-a30480a2ff81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['new_row'] = df_small.content_en.apply(tokenize_column)

# %%
# %%time
df["tokenized_content"] = df.content_en.apply(tokenize_column)
# Out:
# Wall time: 19min 15s

# %%
df.to_csv(r"D:\data\openparliament\hansards_with_party_tokenized_en.csv")

# %%
df.tokenized_content.head()
# Out:
# 0                               [(, return, tabled, )]
# 1    [mr., speaker, ,, i, rise, on, a, point, of, o...
# 2    [finally, ,, mr., speaker, ,, i, ask, that, al...
# 3                                          [agreed, .]
# 4                                [is, that, agreed, ?]
# Name: tokenized_content, dtype: object

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
tokens = df.tokenized_content[2]

# %%
def remove_stopwords(word_tokens):
    words = [w for w in word_tokens if not w in stop_words]
    return words

# %%
remove_stopwords(word_tokens=tokens)
# Out:
# ['finally',
#  ',',
#  'mr.',
#  'speaker',
#  ',',
#  'ask',
#  'remaining',
#  'questions',
#  'allowed',
#  'stand',
#  '.']

# %%
tokens
# Out:
# ['finally',
#  ',',
#  'mr.',
#  'speaker',
#  ',',
#  'i',
#  'ask',
#  'that',
#  'all',
#  'remaining',
#  'questions',
#  'be',
#  'allowed',
#  'to',
#  'stand',
#  '.']

# %%
# Out:
# '\\N'
