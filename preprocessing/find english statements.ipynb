# %%
import pandas as pd

# %% [markdown]
# things that should happen:
#
#     - lowercase
#     - remove stopwords
#     - lemmatize
#
# first thing: remove all non-english statements for the time being

# %%
df = pd.read_csv(r"D:\data\openparliament\time_statements.csv", sep="\t", header=None)
# Out:
# C:\Users\alecr\Anaconda3\envs\openparliament\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,4,12,16,21,22,23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
column_names = ['id', 'document_id', 'time', 'h1_en', 'h2_en', 'member_id', 'who_en', 'content_en', 'sequence_en', 
                'wordcount', 'politician_id', 'procedural', 'h3_en','who_hocid', 'content_fr','statement_type', 'written_question', 'source_id',
                'who_context_en', "slug", 'urlcache', 'h1_fr', 'h2_fr', 'h3_fr', 'who_fr', 'who_context_fr', 'wordcount_en']

# %%
df.columns = column_names

# %%
df.head()
# Out:
#        id  document_id                    time                h1_en  \
# 0  645328          388  2008-02-14 13:15:00-05  Routine Proceedings
# 1  232373         1878  2001-05-03 13:50:00-04    Government Orders
# 2  645329          388  2008-02-14 13:15:00-05  Routine Proceedings
# 3  291892         1748  2003-03-25 10:05:00-05                  NaN
# 4  232374         1878  2001-05-03 13:50:00-04    Government Orders
#
#                                         h2_en member_id  \
# 0      Questions Passed as Orders for Returns        \N
# 1  Federal-Provincial Fiscal Arrangements Act      2611
# 2      Questions Passed as Orders for Returns      1534
# 3                                         NaN        \N
# 4  Federal-Provincial Fiscal Arrangements Act        \N
#
#                             who_en  \
# 0                              NaN
# 1            Ms. Marlene Catterall
# 2                 Mr. Tom Lukiwski
# 3                Some hon. members
# 4  The Acting Speaker (Mr. Bélair)
#
#                                           content_en  sequence_en  wordcount  \
# 0  <p class="procedural" data-HoCid="906765">(Ret...           86          2
# 1  <p>Mr. Speaker, I rise on a point of order. I ...           89         39
# 2  <p data-HoCid="906766" data-originallang="en">...           87         13
# 3                                     <p>Agreed.</p>            1          1
# 4                             <p>Is that agreed?</p>           90          3
#
#    ... source_id                                     who_context_en  \
# 0  ...   p906765                                                NaN
# 1  ...       NaN                                                NaN
# 2  ...   2324890  Parliamentary Secretary to the Leader of the G...
# 3  ...       NaN                                                NaN
# 4  ...       NaN                                                NaN
#
#                              slug  \
# 0                    procedural-3
# 1             marlene-catterall-1
# 2                  tom-lukiwski-7
# 3              some-hon-members-1
# 4  the-acting-speaker-mr-belair-9
#
#                                             urlcache h1_fr h2_fr h3_fr who_fr  \
# 0                   /debates/2008/2/14/procedural-3/   NaN   NaN   NaN    NaN
# 1             /debates/2001/5/3/marlene-catterall-1/   NaN   NaN   NaN    NaN
# 2                 /debates/2008/2/14/tom-lukiwski-7/   NaN   NaN   NaN    NaN
# 3             /debates/2003/3/25/some-hon-members-1/   NaN   NaN   NaN    NaN
# 4  /debates/2001/5/3/the-acting-speaker-mr-belair-9/   NaN   NaN   NaN    NaN
#
#   who_context_fr wordcount_en
# 0            NaN           \N
# 1            NaN           \N
# 2            NaN           \N
# 3            NaN           \N
# 4            NaN           \N
#
# [5 rows x 27 columns]

# %%
df.h1_en.isna().sum()
# Out:
# 1841911

# %%
df_en = df[df.h2_en.notnull()]

# %%
df.h2_en.isna().sum()
# Out:
# 1845428

# %%
df.shape
# Out:
# (2496224, 27)

# %%
df.h2_en.isna().sum() + df.h2_fr.isna().sum()
# Out:
# 4126195

# %%
df_en.head()
# Out:
#        id  document_id                    time                h1_en  \
# 0  645328          388  2008-02-14 13:15:00-05  Routine Proceedings
# 1  232373         1878  2001-05-03 13:50:00-04    Government Orders
# 2  645329          388  2008-02-14 13:15:00-05  Routine Proceedings
# 4  232374         1878  2001-05-03 13:50:00-04    Government Orders
# 5  232375         1878  2001-05-03 13:50:00-04    Government Orders
#
#                                         h2_en member_id  \
# 0      Questions Passed as Orders for Returns        \N
# 1  Federal-Provincial Fiscal Arrangements Act      2611
# 2      Questions Passed as Orders for Returns      1534
# 4  Federal-Provincial Fiscal Arrangements Act        \N
# 5  Federal-Provincial Fiscal Arrangements Act        \N
#
#                             who_en  \
# 0                              NaN
# 1            Ms. Marlene Catterall
# 2                 Mr. Tom Lukiwski
# 4  The Acting Speaker (Mr. Bélair)
# 5                Some hon. members
#
#                                           content_en  sequence_en  wordcount  \
# 0  <p class="procedural" data-HoCid="906765">(Ret...           86          2
# 1  <p>Mr. Speaker, I rise on a point of order. I ...           89         39
# 2  <p data-HoCid="906766" data-originallang="en">...           87         13
# 4                             <p>Is that agreed?</p>           90          3
# 5                                     <p>Agreed.</p>           91          1
#
#    ... source_id                                     who_context_en  \
# 0  ...   p906765                                                NaN
# 1  ...       NaN                                                NaN
# 2  ...   2324890  Parliamentary Secretary to the Leader of the G...
# 4  ...       NaN                                                NaN
# 5  ...       NaN                                                NaN
#
#                              slug  \
# 0                    procedural-3
# 1             marlene-catterall-1
# 2                  tom-lukiwski-7
# 4  the-acting-speaker-mr-belair-9
# 5             some-hon-members-13
#
#                                             urlcache h1_fr h2_fr h3_fr who_fr  \
# 0                   /debates/2008/2/14/procedural-3/   NaN   NaN   NaN    NaN
# 1             /debates/2001/5/3/marlene-catterall-1/   NaN   NaN   NaN    NaN
# 2                 /debates/2008/2/14/tom-lukiwski-7/   NaN   NaN   NaN    NaN
# 4  /debates/2001/5/3/the-acting-speaker-mr-belair-9/   NaN   NaN   NaN    NaN
# 5             /debates/2001/5/3/some-hon-members-13/   NaN   NaN   NaN    NaN
#
#   who_context_fr wordcount_en
# 0            NaN           \N
# 1            NaN           \N
# 2            NaN           \N
# 4            NaN           \N
# 5            NaN           \N
#
# [5 rows x 27 columns]

# %%
df.content_en[1]
# Out:
# '<p>Mr. Speaker, I rise on a point of order. I believe you would find unanimous consent following consultation among all parties to further defer the vote just deferred until Monday to next Tuesday at the end of government orders.</p>'

# %%
df.who_fr.isna().sum()
# Out:
# 1494389

# %%
df.who_en.isna().sum()
# Out:
# 16978

# %%
2496224 - 1494389 #number of rows where someone is talking in french, possibly
# Out:
# 1001835

# %%
en_df = df[df.who_fr.isna()]

# %%
fr_df.head()
# Out:
#               id  document_id                    time              h1_en  \
# 1449095  1874757        15523  2013-06-13 16:50:00-04                NaN
# 1449137  1874978        15523  2013-06-13 22:20:00-04                NaN
# 1449211  1877054        15523  2013-06-18 13:05:00-04                NaN
# 1449691  1878563        15532  2013-10-17 11:25:00-04  Government Orders
# 1449952  1876865        15523  2013-06-18 10:00:00-04                NaN
#
#                     h2_en member_id                    who_en  \
# 1449095               NaN      4115  Ms. Rathika Sitsabaiesan
# 1449137               NaN        \N            An hon. member
# 1449211               NaN        \N         Some hon. members
# 1449691  Canadian Economy      1244        Mr. Kevin Sorenson
# 1449952               NaN      4105  Ms. Jinny Jogindera Sims
#
#                                                 content_en  sequence_en  \
# 1449095  <p data-HoCid="3428551" data-originallang="en"...          463
# 1449137  <p data-HoCid="3429164" data-originallang="en"...          684
# 1449211  <p data-HoCid="3432808" data-originallang="en"...         2760
# 1449691  <p class="procedural" data-HoCid="3438894">mov...           48
# 1449952  <p data-HoCid="3432491" data-originallang="en"...         2571
#
#          wordcount  ... source_id                who_context_en  \
# 1449095       1107  ...  p3428551  Scarborough—Rouge River, NDP
# 1449137          4  ...  p3429164                           NaN
# 1449211          1  ...  p3432808                           NaN
# 1449691       2381  ...   8098002                           NaN
# 1449952          2  ...   8091563                           NaN
#
#                             slug  \
# 1449095  rathika-sitsabaiesan-31
# 1449137         an-hon-member-12
# 1449211      some-hon-members-16
# 1449691         kevin-sorenson-1
# 1449952           jinny-sims-272
#
#                                                   urlcache  \
# 1449095  /committees/immigration/41-1/84/rathika-sitsab...
# 1449137  /committees/immigration/41-1/84/an-hon-member-12/
# 1449211  /committees/immigration/41-1/84/some-hon-membe...
# 1449691              /debates/2013/10/17/kevin-sorenson-1/
# 1449952    /committees/immigration/41-1/84/jinny-sims-272/
#
#                               h1_fr                  h2_fr h3_fr  \
# 1449095                         NaN                    NaN   NaN
# 1449137                         NaN                    NaN   NaN
# 1449211                         NaN                    NaN   NaN
# 1449691  Initiatives ministérielles  L'économie canadienne   NaN
# 1449952                         NaN                    NaN   NaN
#
#                            who_fr                who_context_fr wordcount_en
# 1449095  Mme Rathika Sitsabaiesan  Scarborough—Rouge River, NPD           \N
# 1449137                  Une voix                           NaN           \N
# 1449211                  Des voix                           NaN           \N
# 1449691         M. Kevin Sorenson                           NaN           \N
# 1449952  Mme Jinny Jogindera Sims                           NaN           \N
#
# [5 rows x 27 columns]

# %%
en_df
# Out:
#               id  document_id                    time                h1_en  \
# 0         645328          388  2008-02-14 13:15:00-05  Routine Proceedings
# 1         232373         1878  2001-05-03 13:50:00-04    Government Orders
# 2         645329          388  2008-02-14 13:15:00-05  Routine Proceedings
# 3         291892         1748  2003-03-25 10:05:00-05                  NaN
# 4         232374         1878  2001-05-03 13:50:00-04    Government Orders
# ...          ...          ...                     ...                  ...
# 2495940  2917499        21073  2020-09-29 15:50:00-04  Routine Proceedings
# 2495961  2917531        21073  2020-09-29 16:25:00-04    Government Orders
# 2496002  2917571        21073  2020-09-29 17:45:00-04    Government Orders
# 2496080  2917653        21073  2020-09-29 21:30:00-04    Government Orders
# 2496206  2917777        21073  2020-09-30 03:05:00-04    Government Orders
#
#                                                      h2_en member_id  \
# 0                   Questions Passed as Orders for Returns        \N
# 1               Federal-Provincial Fiscal Arrangements Act      2611
# 2                   Questions Passed as Orders for Returns      1534
# 3                                                      NaN        \N
# 4               Federal-Provincial Fiscal Arrangements Act        \N
# ...                                                    ...       ...
# 2495940                                Peschisolido Report        \N
# 2495961  Proceedings on the bill entitled An Act relati...        \N
# 2496002  Proceedings on the bill entitled An Act relati...        \N
# 2496080  Proceedings on the bill entitled An Act relati...        \N
# 2496206                     COVID-19 Response Measures Act        \N
#
#                                   who_en  \
# 0                                    NaN
# 1                  Ms. Marlene Catterall
# 2                       Mr. Tom Lukiwski
# 3                      Some hon. members
# 4        The Acting Speaker (Mr. Bélair)
# ...                                  ...
# 2495940                              NaN
# 2495961                              NaN
# 2496002                              NaN
# 2496080                              NaN
# 2496206                              NaN
#
#                                                 content_en  sequence_en  \
# 0        <p class="procedural" data-HoCid="906765">(Ret...           86
# 1        <p>Mr. Speaker, I rise on a point of order. I ...           89
# 2        <p data-HoCid="906766" data-originallang="en">...           87
# 3                                           <p>Agreed.</p>            1
# 4                                   <p>Is that agreed?</p>           90
# ...                                                    ...          ...
# 2495940  <p class="procedural" data-HoCid="6270228"> <e...          222
# 2495961  <p class="procedural" data-HoCid="6270315">The...          254
# 2496002  <p class="procedural" data-HoCid="6270499">The...          294
# 2496080  <p class="procedural" data-HoCid="6270819">(Th...          376
# 2496206  <p class="procedural" data-HoCid="6271416">(Th...          500
#
#          wordcount  ... source_id  \
# 0                2  ...   p906765
# 1               39  ...       NaN
# 2               13  ...   2324890
# 3                1  ...       NaN
# 4                3  ...       NaN
# ...            ...  ...       ...
# 2495940          0  ...  p6270228
# 2495961          0  ...  p6270315
# 2496002          0  ...  p6270499
# 2496080          0  ...  p6270819
# 2496206          0  ...  p6271416
#
#                                             who_context_en  \
# 0                                                      NaN
# 1                                                      NaN
# 2        Parliamentary Secretary to the Leader of the G...
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 2495940                                                NaN
# 2495961                                                NaN
# 2496002                                                NaN
# 2496080                                                NaN
# 2496206                                                NaN
#
#                                    slug  \
# 0                          procedural-3
# 1                   marlene-catterall-1
# 2                        tom-lukiwski-7
# 3                    some-hon-members-1
# 4        the-acting-speaker-mr-belair-9
# ...                                 ...
# 2495940                    procedural-3
# 2495961                    procedural-6
# 2496002                    procedural-7
# 2496080                    procedural-9
# 2496206                   procedural-10
#
#                                                   urlcache  \
# 0                         /debates/2008/2/14/procedural-3/
# 1                   /debates/2001/5/3/marlene-catterall-1/
# 2                       /debates/2008/2/14/tom-lukiwski-7/
# 3                   /debates/2003/3/25/some-hon-members-1/
# 4        /debates/2001/5/3/the-acting-speaker-mr-belair-9/
# ...                                                    ...
# 2495940                   /debates/2020/9/29/procedural-3/
# 2495961                   /debates/2020/9/29/procedural-6/
# 2496002                   /debates/2020/9/29/procedural-7/
# 2496080                   /debates/2020/9/29/procedural-9/
# 2496206                  /debates/2020/9/29/procedural-10/
#
#                                   h1_fr  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2495940              Affaires courantes
# 2495961  Ordres émanant du gouvernement
# 2496002  Ordres émanant du gouvernement
# 2496080  Ordres émanant du gouvernement
# 2496206  Ordres émanant du gouvernement
#
#                                                      h2_fr h3_fr who_fr  \
# 0                                                      NaN   NaN    NaN
# 1                                                      NaN   NaN    NaN
# 2                                                      NaN   NaN    NaN
# 3                                                      NaN   NaN    NaN
# 4                                                      NaN   NaN    NaN
# ...                                                    ...   ...    ...
# 2495940                            Le rapport Peschisolido   NaN    NaN
# 2495961  Délibérations sur le projet de loi intitulé Lo...   NaN    NaN
# 2496002  Délibérations sur le projet de loi intitulé Lo...   NaN    NaN
# 2496080  Délibérations sur le projet de loi intitulé Lo...   NaN    NaN
# 2496206       Loi sur des mesures en réponse à la COVID-19   NaN    NaN
#
#         who_context_fr wordcount_en
# 0                  NaN           \N
# 1                  NaN           \N
# 2                  NaN           \N
# 3                  NaN           \N
# 4                  NaN           \N
# ...                ...          ...
# 2495940            NaN            0
# 2495961            NaN            0
# 2496002            NaN            0
# 2496080            NaN            0
# 2496206            NaN            0
#
# [1494389 rows x 27 columns]

# %%
en_df.to_csv(r"D:\data\openparliament\parliamentary_statements_en.csv")
